# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
from scipy.stats import alpha 
# %matplotlib inline

# %%
alp = 4.5

alpha_rv = alpha(alp)
sample_data = alpha_rv.rvs(1000)

x = np.linspace(0,0.5, 50)
pdf = alpha.pdf(x, alp)

plt.plot(x, pdf, label = 'teoretical pdf', c= 'r')
plt.hist(sample_data, bins=25, normed=True, color='g',label='actual')
plt.legend()
plt.ylabel('$F(x)$')
plt.xlabel('$x$')

# %%
mu_teor = alp**-1
var_teor = alp**-2
sigma_teor = math.sqrt(alp**-2)
print 'Теоретическое среднее: {:.2f}'.format(mu_teor)
print 'Теоретическая дисперсия: {:.2f}'.format(var_teor)
print 'Теоретическое стандартное отклонение: {:.2f}'.format(sigma_teor)
# Out:
# Теоретическое среднее: 0.18
# Теоретическая дисперсия: 0.03
# Теоретическое стандартное отклонение: 0.18

# %%
def gen(sample, n_sample, n_samples=1000):
    means = []
    for i in range(n_samples):
        sub_sample = sample[np.random.randint(0,len(sample), n_sample)]
        means.append(np.mean(sub_sample))
    
    mu = np.mean(means)
    sigma = np.std(means,ddof=1)
    SE = sigma_teor/math.sqrt(n_sample) 
    
    norm_rv = sts.norm(mu_teor,SE)
    
    plt.hist(means, normed=True,label='actual')
    plt.plot(x,norm_rv.pdf(x), label='teoretical')
    plt.legend()
    plt.xlabel('$x$')
    plt.ylabel('$F(x)$')
    
    print 'Сравнение параметров теоретических средних с приближенными параметрами нормальных распределений при N = {0}'.format(n_sample)
    print 'Теоретическое среднее и приближенное: {:.2f} - {:.2f}'.format(mu_teor, mu)
    print 'Теоретическое стандартное отклонение и приближенное: {:.2f} - {:.2f}'.format(SE, sigma)
    print 'Теоретическое мат ожидание и стандартная ошибка среднего: {:.2f} +/- {:.2f}'.format(mu, 2*SE)

# %%
gen(sample_data,5)
# Out:
# Сравнение параметров теоретических средних с приближенными параметрами нормальных распределений при N = 5
# Теоретическое среднее и приближенное: 0.18 - 0.19
# Теоретическое стандартное отклонение и приближенное: 0.08 - 0.02
# Теоретическое мат ожидание и стандартная ошибка среднего: 0.19 +/- 0.16

# %%
gen(sample_data,10)
# Out:
# Сравнение параметров теоретических средних с приближенными параметрами нормальных распределений при N = 10
# Теоретическое среднее и приближенное: 0.18 - 0.19
# Теоретическое стандартное отклонение и приближенное: 0.06 - 0.01
# Теоретическое мат ожидание и стандартная ошибка среднего: 0.19 +/- 0.11

# %%
gen(sample_data,30)
# Out:
# Сравнение параметров теоретических средних с приближенными параметрами нормальных распределений при N = 30
# Теоретическое среднее и приближенное: 0.18 - 0.19
# Теоретическое стандартное отклонение и приближенное: 0.03 - 0.01
# Теоретическое мат ожидание и стандартная ошибка среднего: 0.19 +/- 0.07
